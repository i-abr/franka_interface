# %%
import numpy as np
import pickle as pkl

# %%
tr = np.load('desired_trajectory.npy')
trial1 = pkl.load(open('2020-02-21_11-43-12-50_hz-data.pkl', 'rb'), encoding='bytes')
trial_traj = np.stack(trial1[b'state'])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(tr[:,2])
plt.plot(trial_traj[:,2])

# %%
plt.plot(tr[:,1])
plt.plot(trial_traj[:,1])
