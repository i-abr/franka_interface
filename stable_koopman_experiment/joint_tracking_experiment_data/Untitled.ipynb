# %%
import matplotlib.pyplot as plt

# %%
import pickle as pkl
import numpy as np

# %%
data = pkl.load(open('2020-02-21_11-30-21-50_hz-data.pkl', 'rb'),encoding='bytes')

# %%
edata = np.stack(data[b'state'])

# %%
plt.plot(edata[:,1], edata[:,2])
